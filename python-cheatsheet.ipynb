# %% [markdown]
# ## Creating a basic line graph

# %% [markdown]
# ### Start by importing these Python modules

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load in some data

# %%
x = pd.period_range('1980-01-01',periods=410, freq='M')
x = x.to_timestamp().to_pydatetime()
y = np.random.randn(len(x)).cumsum()

# %% [markdown]
# ### Plot the data

# %%
plt.plot(x, y, label='FDI')

# %% [markdown]
# ### Add titles / legends / symbology

# %%
plt.title('Fake Data Index')

plt.xlabel('Date')

plt.ylabel('Index')

plt.grid(True)

plt.figtext(0.995, 0.01, 'Data Source: Bureau of Meteorology, 2016',

ha='right', va='bottom')

plt.legend(loc='best', framealpha=0.5,

prop={'size':'small'})

plt.tight_layout(pad=1)

plt.gcf().set_size_inches(8, 4)

plt.plot(x, y, label='FDI')
